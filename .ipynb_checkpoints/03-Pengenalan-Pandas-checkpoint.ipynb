# %% [markdown]
# # Pengenalan Pandas

# %% [markdown]
# Oleh Afif Akbar Iskandar

# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)
# Out:
# /Users/afifai/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Membaca CSV

# %% [markdown]
# Kita dapat membaca file berformat CSV dengan fungsi `read_csv`. Secara default diasumsikan dipisahkan oleh koma.
#
# Berikut adalah cara membaca CSV menggunakan Pandas

# %%
data_frame = pd.read_csv('data/train.csv',index_col='PassengerId')

# %%
data_frame[:3]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ## Memilih Kolom

# %% [markdown]
# Untuk memilih kolom, panggil `data_frame['nama_kolom']`

# %%
data_frame['Fare']
# Out:
# PassengerId
# 1        7.2500
# 2       71.2833
# 3        7.9250
# 4       53.1000
# 5        8.0500
# 6        8.4583
# 7       51.8625
# 8       21.0750
# 9       11.1333
# 10      30.0708
# 11      16.7000
# 12      26.5500
# 13       8.0500
# 14      31.2750
# 15       7.8542
# 16      16.0000
# 17      29.1250
# 18      13.0000
# 19      18.0000
# 20       7.2250
# 21      26.0000
# 22      13.0000
# 23       8.0292
# 24      35.5000
# 25      21.0750
# 26      31.3875
# 27       7.2250
# 28     263.0000
# 29       7.8792
# 30       7.8958
#          ...
# 862     11.5000
# 863     25.9292
# 864     69.5500
# 865     13.0000
# 866     13.0000
# 867     13.8583
# 868     50.4958
# 869      9.5000
# 870     11.1333
# 871      7.8958
# 872     52.5542
# 873      5.0000
# 874      9.0000
# 875     24.0000
# 876      7.2250
# 877      9.8458
# 878      7.8958
# 879      7.8958
# 880     83.1583
# 881     26.0000
# 882      7.8958
# 883     10.5167
# 884     10.5000
# 885      7.0500
# 886     29.1250
# 887     13.0000
# 888     30.0000
# 889     23.4500
# 890     30.0000
# 891      7.7500
# Name: Fare, dtype: float64

# %% [markdown]
# ## Menggambar plot pada kolom

# %% [markdown]
# hanya menambahkan `.plot()` pada akhir `data_frame`

# %%
data_frame['Fare'].plot()

# %%
data_frame.plot()

# %% [markdown]
# ## Memilih Kolom dan Baris

# %% [markdown]
# Memilih kolom dengan 5 data teratas

# %%
data_frame['Fare'][:5]
# Out:
# PassengerId
# 1     7.2500
# 2    71.2833
# 3     7.9250
# 4    53.1000
# 5     8.0500
# Name: Fare, dtype: float64

# %% [markdown]
# Multiple Columns

# %%
data_frame[['Fare','Pclass']][:5]
# Out:
#                 Fare  Pclass
# PassengerId
# 1             7.2500       3
# 2            71.2833       1
# 3             7.9250       3
# 4            53.1000       1
# 5             8.0500       3

# %% [markdown]
# Melihat jumlah penumpang pada tiap kelas

# %%
data_frame['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
jumlah_per_kelas = data_frame['Pclass'].value_counts()
jumlah_per_kelas.plot(kind='bar')
